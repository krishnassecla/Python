# %%
f = open("/home/pravesh/Desktop/Python/decorators.py")
lines = f.readlines() #returns a list on line strings
lines
# Out:
# ['# def outer():\n',
#  '#     x = 5\n',
#  '\n',
#  '#     def inner():\n',
#  '#         print(5)\n',
#  '\n',
#  '#     inner()\n',
#  '\n',
#  '\n',
#  '# outer()\n',
#  '\n',
#  '\n',
#  '# @uppercase_decorator\n',
#  '# def say_hi():\n',
#  '#     return "hello there"\n',
#  '\n',
#  '\n',
#  '# print(say_hi())\n',
#  '\n',
#  '# def uppercase_decorator(function):\n',
#  '#     def wrapper():\n',
#  '#         func = function()\n',
#  '#         make_uppercase = func.upper()\n',
#  '#         return make_uppercase\n',
#  '\n',
#  '#     return wrapper\n',
#  '\n',
#  '# def split_str(function):\n',
#  '#     def wrapper():\n',
#  '#         func = function()\n',
#  '#         splitted_str = func.split()\n',
#  '#         return splitted_str\n',
#  '\n',
#  '#     return wrapper\n',
#  '\n',
#  '# @split_str\n',
#  '# @uppercase_decorator\n',
#  '# def say_hi():\n',
#  '#     return "Hey there"\n',
#  '\n',
#  '# say_hi()\n',
#  '\n',
#  '\n',
# ...

# %%
lines = [line.rstrip() for line in lines]
lines
# Out:
# ['# def outer():',
#  '#     x = 5',
#  '',
#  '#     def inner():',
#  '#         print(5)',
#  '',
#  '#     inner()',
#  '',
#  '',
#  '# outer()',
#  '',
#  '',
#  '# @uppercase_decorator',
#  '# def say_hi():',
#  '#     return "hello there"',
#  '',
#  '',
#  '# print(say_hi())',
#  '',
#  '# def uppercase_decorator(function):',
#  '#     def wrapper():',
#  '#         func = function()',
#  '#         make_uppercase = func.upper()',
#  '#         return make_uppercase',
#  '',
#  '#     return wrapper',
#  '',
#  '# def split_str(function):',
#  '#     def wrapper():',
#  '#         func = function()',
#  '#         splitted_str = func.split()',
#  '#         return splitted_str',
#  '',
#  '#     return wrapper',
#  '',
#  '# @split_str',
#  '# @uppercase_decorator',
#  '# def say_hi():',
#  '#     return "Hey there"',
#  '',
#  '# say_hi()',
#  '',
#  '',
#  'def decorator_function(msg):',
#  '    print("I am inside the decorator_funciton.")',
# ...

# %%
    lines = [line.rstrip() for line in open('')]
